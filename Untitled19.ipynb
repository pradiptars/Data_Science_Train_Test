# %% [markdown]
# <a href="https://colab.research.google.com/github/pradiptars/Data_Science_Train_Test/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Train and Test Data

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df = sns.load_dataset('titanic')

# %%
df.keys()
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df2 = df[['survived', 'pclass','age','parch']]
df3 = df2.fillna(df2.mean())
df3
# Out:
#      survived  pclass        age  parch
# 0           0       3  22.000000      0
# 1           1       1  38.000000      0
# 2           1       3  26.000000      0
# 3           1       1  35.000000      0
# 4           0       3  35.000000      0
# ..        ...     ...        ...    ...
# 886         0       2  27.000000      0
# 887         1       1  19.000000      0
# 888         0       3  29.699118      2
# 889         1       1  26.000000      0
# 890         0       3  32.000000      0
#
# [891 rows x 4 columns]

# %%
X = df3.drop('survived', axis=1)
y = df3['survived']
print(X.shape)
print(y.shape)
# Out:
# (891, 3)
# (891,)

# %%
X_train, y_train, X_test, y_test = train_test_split(X, y, test_size=0.2, random_state=51)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (712, 3) (179, 3)
# (712,) (179,)

# %%
X_train
# Out:
#      pclass        age  parch
# 770       3  24.000000      0
# 152       3  55.500000      0
# 731       3  11.000000      0
# 775       3  18.000000      0
# 324       3  29.699118      2
# ..      ...        ...    ...
# 528       3  39.000000      0
# 709       3  29.699118      1
# 736       3  48.000000      3
# 485       3  29.699118      1
# 57        3  28.500000      0
#
# [712 rows x 3 columns]
